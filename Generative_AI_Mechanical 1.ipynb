# %%
from langchain_community.document_loaders import TextLoader
loadder  = TextLoader('CNC.txt',encoding="utf-8")
loadder
# Out:
# /tmp/ipykernel_1929/2056746616.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
text_documents = loadder.load()
text_documents
# Out:
# [Document(metadata={'source': 'CNC.txt'}, page_content="1) What is a CNC Machine?\nDefinition (Interview Answer)\n\nA CNC (Computer Numerical Control) machine is an automated manufacturing machine that is controlled by a computer using pre-programmed instructions called G-code. It performs machining operations such as cutting, drilling, milling, turning, and boring with high accuracy and repeatability, without requiring continuous manual operation.\n\nSimple Explanation\n\nImagine you want to carve a complex shape on a metal block.\n\nIn a conventional machine, the operator manually moves the cutting tool.\nIn a CNC machine, the operator only loads the program and the workpiece.\nThe computer automatically controls the movement of the cutting tool in the X, Y, and Z directions to produce the required part.\n\nThat's why CNC machines are faster, more accurate, and suitable for mass production.\n\nFull Form\n\nCNC = Computer Numerical Control\n\nComputer → Controls the machine\nNumerical → Uses numbers and coordinates\nControl → Controls machine movements automatically\nWorking Principle\n\nThe working of a CNC machine involves the following steps:\n\nA part is designed using CAD software.\nThe CAD model is converted into a CAM program.\nCAM software generates G-code.\nThe G-code is loaded into the CNC controller.\nThe operator fixes the workpiece and tool.\nServo motors move the machine axes according to the program.\nThe cutting tool removes material to produce the final component.\nMain Components of a CNC Machine\nCNC Controller\nMachine Bed\nSpindle\nCutting Tool\nTool Magazine (ATC)\nServo Motors\nBall Screws\nGuideways\nCoolant System\nWorkholding Device (Vice/Chuck)\nTypes of CNC Machines\nCNC Lathe Machine\nCNC Milling Machine\nCNC Turning Center\nCNC Vertical Machining Center (VMC)\nCNC Horizontal Machining Center (HMC)\nCNC Grinding Machine\nCNC EDM Machine\nCNC Laser Cutting Machine\nCNC Plasma Cutting Machine\nCNC Router\nAdvantages\nHigh accuracy (up to ±0.005 mm or better)\nExcellent repeatability\nFaster production\nReduced human error\nCan manufacture complex geometries\nBetter surface finish\nLower production cost in mass manufacturing\nImproved safety\nDisadvantages\nHigh initial investment\nSkilled programmer required\nMaintenance cost is high\nProgramming errors can damage tools or workpieces\nLess economical for very small production quantities\nApplications\n\nCNC machines are widely used in:\n\nAutomotive industry\nAerospace industry\nMedical equipment manufacturing\nDefence manufacturing\nMold and die making\nElectronics industry\nPrecision engineering\nRailway component manufacturing\nCommon Operations Performed\nTurning\nFacing\nDrilling\nMilling\nBoring\nTapping\nReaming\nThread Cutting\nGrooving\nReal-Life Example\n\nA company like Tata Motors needs 10,000 identical engine components.\n\nInstead of machining each component manually, a CNC machine is programmed once. It then manufactures all 10,000 parts with nearly identical dimensions, ensuring high quality, speed, and consistency.\n\nHow Does a CNC Machine Maintain Accuracy?\n\nA CNC machine maintains accuracy by combining precise mechanical components, electronic feedback systems, and computer-controlled motion. These elements work together to ensure that the cutting tool follows the programmed path with minimal error.\n\n1. Closed-Loop Feedback System\n\nModern CNC machines use a closed-loop control system, where sensors (encoders) continuously monitor the position of the machine axes. The CNC controller compares the actual position with the programmed position and instantly corrects any deviation. This ensures highly accurate tool movement.\n\n2. Servo Motors\n\nServo motors drive the machine axes with high precision. They provide accurate control over position, speed, and torque, allowing smooth and repeatable movements even during complex machining operations.\n\n3. Ball Screws\n\nBall screws convert the rotary motion of the servo motor into l ...

# %%
# Text splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)
finalDocuments = textSplitter.split_documents(text_documents)
finalDocuments
# Out:
# [Document(metadata={'source': 'CNC.txt'}, page_content='1) What is a CNC Machine?\nDefinition (Interview Answer)'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC (Computer Numerical Control) machine is an automated manufacturing machine that is controlled by a computer using pre-programmed instructions called G-code. It performs machining operations'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='operations such as cutting, drilling, milling, turning, and boring with high accuracy and repeatability, without requiring continuous manual operation.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Simple Explanation\n\nImagine you want to carve a complex shape on a metal block.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='In a conventional machine, the operator manually moves the cutting tool.\nIn a CNC machine, the operator only loads the program and the workpiece.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='The computer automatically controls the movement of the cutting tool in the X, Y, and Z directions to produce the required part.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content="That's why CNC machines are faster, more accurate, and suitable for mass production.\n\nFull Form\n\nCNC = Computer Numerical Control"),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Computer → Controls the machine\nNumerical → Uses numbers and coordinates\nControl → Controls machine movements automatically\nWorking Principle'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='The working of a CNC machine involves the following steps:'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A part is designed using CAD software.\nThe CAD model is converted into a CAM program.\nCAM software generates G-code.\nThe G-code is loaded into the CNC controller.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='The operator fixes the workpiece and tool.\nServo motors move the machine axes according to the program.\nThe cutting tool removes material to produce the final component.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Main Components of a CNC Machine\nCNC Controller\nMachine Bed\nSpindle\nCutting Tool\nTool Magazine (ATC)\nServo Motors\nBall Screws\nGuideways\nCoolant System\nWorkholding Device (Vice/Chuck)'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Types of CNC Machines\nCNC Lathe Machine\nCNC Milling Machine\nCNC Turning Center\nCNC Vertical Machining Center (VMC)\nCNC Horizontal Machining Center (HMC)\nCNC Grinding Machine\nCNC EDM Machine'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC EDM Machine\nCNC Laser Cutting Machine\nCNC Plasma Cutting Machine\nCNC Router\nAdvantages\nHigh accuracy (up to ±0.005 mm or better)\nExcellent repeatability\nFaster production\nReduced human error'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Reduced human error\nCan manufacture complex geometries\nBetter surface finish\nLower production cost in mass manufacturing\nImproved safety\nDisadvantages\nHigh initial investment'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Skilled programmer required\nMaintenance cost is high\nProgramming errors can damage tools or workpieces\nLess economical for very small production quantities\nApplications'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC machines are widely used in:'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Automotive industry\nAerospace industry\nMedical equipment manufacturing\nDefence manufacturing\nMold and die making\nElectronics industry\nPrecision engineering\nRailway component manufacturing'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Common Operations Performed\nTurning\nFacing\nDrilling\nMilling\nBoring\nTapping\nReaming\nThread Cutting\nGrooving\nReal-Life Example'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A company like Tata Motors needs 10,000 identical engine components.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Instead of machining each component manually, a CNC machine is programmed once. It then manufactures all 10,000 parts with nearly identical dimensions, ensuring high quality, speed, and consistency.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='How Does a CNC Machine Maintain Accuracy?'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC machine maintains accuracy by combining precise mechanical components, electronic feedback systems, and computer-controlled motion. These elements work together to ensure that the cutting tool'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='the cutting tool follows the programmed path with minimal error.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='1. Closed-Loop Feedback System'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Modern CNC machines use a closed-loop control system, where sensors (encoders) continuously monitor the position of the machine axes. The CNC controller compares the actual position with the'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='position with the programmed position and instantly corrects any deviation. This ensures highly accurate tool movement.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='2. Servo Motors'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Servo motors drive the machine axes with high precision. They provide accurate control over position, speed, and torque, allowing smooth and repeatable movements even during complex machining'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='complex machining operations.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='3. Ball Screws'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Ball screws convert the rotary motion of the servo motor into linear motion. Due to their low friction and minimal backlash, they enable precise positioning and reduce mechanical errors.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='4. Linear Guideways'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Linear guideways provide smooth and rigid movement of the machine axes. They minimize vibration and maintain accurate alignment of the cutting tool throughout the machining process.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='5. Rigid Machine Structure'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='The machine frame is typically made of cast iron or other rigid materials. A strong structure reduces vibration and deformation during machining, helping maintain dimensional accuracy and improving'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and improving surface finish.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='6. Tool Compensation'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Different cutting tools have different lengths and diameters. CNC machines use tool offset values to compensate for these variations, ensuring that machining dimensions remain accurate even after'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='accurate even after tool changes.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='7. Thermal Compensation'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Heat generated during machining can cause machine components to expand, affecting accuracy. Coolant systems, temperature sensors, and thermal compensation features help minimize these errors.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='8. Accurate Workholding\n\nFixtures, vises, and chucks securely hold the workpiece in place. Proper clamping prevents movement during machining, ensuring consistent and precise results.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='9. High-Quality Cutting Tools\n\nSharp and well-maintained cutting tools reduce cutting forces, tool deflection, and wear, which contributes to better dimensional accuracy and surface quality.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='10. Regular Calibration and Maintenance'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Periodic calibration ensures that the machine axes, spindle, and measuring systems remain aligned and accurate. Routine maintenance also helps prevent wear-related errors and extends machine life.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Conclusion'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC machine maintains accuracy through the combined action of closed-loop feedback control, precision servo motors, ball screws, rigid construction, tool and thermal compensation, accurate'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='accurate workholding, and regular calibration. These features enable CNC machines to consistently produce components with high precision and repeatability, making them suitable for industries such as'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='industries such as automotive, aerospace, medical, and precision engineering.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A comprehensive guide would include topics such as:'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='History of CNC\nEvolution from manual machines\nNumerical Control (NC) era (1940s–1950s)\nDevelopment by John T. Parsons and MIT\nTransition from NC to CNC\nCAD/CAM integration'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CAD/CAM integration\nIndustry 4.0 and Smart Manufacturing\nFundamentals\nWhat is CNC?\nWorking principle\nMachine architecture\nCoordinate systems\nMachine axes (X, Y, Z, A, B, C)'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Open-loop vs. closed-loop control\nMachine Components\nMachine bed\nSpindle\nBall screws\nLinear guideways\nServo motors\nEncoders\nTool magazine and ATC\nCoolant and lubrication systems\nCNC controller'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC controller\nWorkholding devices\nTypes of CNC Machines\nCNC Lathe\nCNC Milling Machine\nVMC\nHMC\nCNC Grinding\nCNC EDM\nWire EDM\nLaser Cutting\nPlasma Cutting\nWater Jet Cutting\nCNC Routers\nSwiss-type CNC'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Swiss-type CNC\nProgramming\nG-codes\nM-codes\nTool offsets\nCoordinate systems (G54–G59)\nTool radius compensation\nCanned cycles\nMacro programming\nCAM software workflow\nMachining Operations\nTurning\nFacing'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Turning\nFacing\nBoring\nDrilling\nReaming\nTapping\nMilling\nPocketing\nContouring\nThreading\nGrooving\nCalculations (with derivations and solved examples)\nSpindle speed (RPM)\nCutting speed\nFeed rate'),
#  Document(metadata={'source': 'CNC.txt'}, page_content="Feed rate\nFeed per tooth\nMaterial Removal Rate (MRR)\nMachining time\nDepth of cut\nWidth of cut\nPower required\nTorque\nChip load\nSurface roughness estimation\nTool life (Taylor's Tool Life Equation)"),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Cutting forces\nCNC interpolation\nAccuracy and tolerance calculations\nGD&T basics\nCost estimation\nProduction time\nCycle time optimization\nMachine utilization and OEE\nMaterials\nSteel\nStainless steel'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Stainless steel\nCast iron\nAluminum\nBrass\nCopper\nTitanium\nComposites\nEngineering plastics\nCutting Tools\nHSS\nCarbide\nCeramic\nCBN\nPCD\nCoatings (TiN, TiAlN, AlCrN, etc.)\nInspection & Quality Control\nCMM'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CMM\nSurface roughness\nDial indicators\nMicrometers\nVernier calipers\nLaser measurement\nProbe systems\nIndustrial Applications\nAutomotive\nAerospace\nMedical\nElectronics\nOil & Gas\nDefence\nRailway'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Defence\nRailway\nMold & Die\nPrecision manufacturing\nCurrent CNC Technologies (2026)\nAI-assisted machining\nDigital twins\nIoT-enabled CNC\nPredictive maintenance\n5-axis simultaneous machining'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Hybrid additive + subtractive manufacturing\nCloud-connected CNC systems\nFuture of CNC (2030–2050)\nAI-generated toolpaths\nAutonomous machining cells\nCollaborative robots (cobots)'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Self-calibrating machines\nDigital factories\nZero-defect manufacturing\nReal-time adaptive machining\nQuantum-assisted optimization (research stage)\nFully autonomous smart factories'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Major CNC Manufacturers\nFANUC\nSiemens\nHaas\nMazak\nDMG MORI\nOkuma\nMakino\nDoosan\nHurco\nMitsubishi Electric\nCommon Problems & Troubleshooting\nChatter\nTool wear\nThermal errors\nBacklash\nVibration'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Backlash\nVibration\nPoor surface finish\nTool breakage\nAlignment issues'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Module 1: CNC Basics\nIntroduction to CNC'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Computer Numerical Control (CNC) is one of the most significant advancements in modern manufacturing technology. It has revolutionized the way components are produced by replacing manual machining'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='manual machining operations with computer-controlled automation. In a CNC machine, the movements of the cutting tool and the workpiece are controlled by a computer program rather than by a human'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='than by a human operator. These programs contain numerical instructions that precisely define the position, speed, feed, and sequence of machining operations. As a result, CNC machines can'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC machines can manufacture highly accurate and complex components with excellent repeatability and minimal human intervention. Today, CNC technology forms the backbone of industries such as'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='industries such as automotive, aerospace, medical device manufacturing, electronics, defence, and precision engineering, where high-quality production and tight dimensional tolerances are essential.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Before the invention of CNC technology, manufacturing relied heavily on conventional machine tools such as lathes, milling machines, drilling machines, and shapers. In these machines, the operator'),
#  Document(metadata={'source': 'CNC.txt'}, page_content="the operator manually controlled every movement of the cutting tool using handwheels and mechanical levers. The quality of the finished product depended greatly on the operator's skill, experience,"),
#  Document(metadata={'source': 'CNC.txt'}, page_content='skill, experience, and concentration. Although conventional machines are still used for repair work, prototype development, and small-batch production, they are less suitable for large-scale'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='for large-scale manufacturing because they are slower, more labor-intensive, and more prone to human error. The need for greater precision, faster production rates, and consistent product quality led'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='product quality led to the development of Numerical Control (NC) machines and, later, Computer Numerical Control (CNC) machines.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='The term Computer Numerical Control refers to a manufacturing system in which a computer controls the motion of machine tools using numerical instructions. The word Computer represents the electronic'),
#  Document(metadata={'source': 'CNC.txt'}, page_content="the electronic controller that processes machining programs. Numerical refers to the use of numerical coordinates and coded instructions to define tool movement. Control indicates that the machine's"),
#  Document(metadata={'source': 'CNC.txt'}, page_content="that the machine's operations are automatically managed according to these programmed instructions. Instead of manually moving the cutting tool, the operator simply loads the machining program into"),
#  Document(metadata={'source': 'CNC.txt'}, page_content='program into the CNC controller, sets up the workpiece and cutting tools, and starts the machining cycle. The controller interprets the program and precisely controls the movement of the machine'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='of the machine axes, spindle speed, feed rate, coolant flow, and tool changes.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC machine operates on the principle of programmed automation. The manufacturing process begins with the design of a component using Computer-Aided Design (CAD) software. The digital model is then'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='model is then transferred to Computer-Aided Manufacturing (CAM) software, where machining strategies are created and converted into machine-readable instructions known as G-code and M-code. These'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and M-code. These codes specify every movement required to manufacture the component, including tool paths, spindle speeds, feed rates, and machining operations. Once the program is loaded into the'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='is loaded into the CNC controller, servo motors move the machine axes with high precision according to the programmed instructions. Feedback devices such as encoders continuously monitor the position'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='the position of the machine axes and send signals back to the controller, allowing it to correct any positional errors in real time. This closed-loop control system enables CNC machines to achieve'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='machines to achieve exceptional levels of accuracy and repeatability.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='One of the defining characteristics of CNC technology is its ability to produce identical components repeatedly without significant variation. This capability is known as repeatability and is one of'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and is one of the primary reasons CNC machines are widely used in mass production. Whether manufacturing ten components or one hundred thousand, the machine follows exactly the same program for every'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='program for every cycle, ensuring that each part conforms to the specified dimensions and quality standards. This consistency reduces product rejection rates, improves production efficiency, and'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='efficiency, and lowers manufacturing costs.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Modern CNC machines are capable of performing a wide range of machining operations, including turning, milling, drilling, boring, tapping, reaming, grinding, threading, slotting, engraving, laser'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='engraving, laser cutting, plasma cutting, and electrical discharge machining (EDM). Depending on the machine configuration, these operations may be performed on two-axis, three-axis, four-axis, or'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='four-axis, or five-axis machines. Advanced multi-axis CNC machines can manufacture highly complex components with curved surfaces and intricate geometries that would be extremely difficult or'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='difficult or impossible to produce using conventional machining methods.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='The widespread adoption of CNC technology has significantly improved manufacturing productivity across industries. Because machine movements are controlled automatically, machining operations can be'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='operations can be completed much faster than manual methods while maintaining superior dimensional accuracy. Human errors are greatly reduced, production planning becomes more predictable, and'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='predictable, and manufacturing processes become more efficient. Furthermore, CNC machines can operate continuously with minimal supervision, making them suitable for automated production lines and'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='lines and smart factories operating under the principles of Industry 4.0.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Despite their many advantages, CNC machines also present certain challenges. The initial investment required to purchase CNC equipment is considerably higher than that for conventional machines. In'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='machines. In addition, skilled personnel are required to create machining programs, operate the machines, perform maintenance, and troubleshoot technical issues. Nevertheless, the long-term benefits'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='long-term benefits of increased productivity, reduced labor costs, improved product quality, and greater manufacturing flexibility generally outweigh these initial costs, making CNC technology an'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC technology an indispensable part of modern engineering and industrial production.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='In conclusion, CNC technology has transformed manufacturing by integrating computer control, precision engineering, and automation into a single system. It enables manufacturers to produce complex'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='to produce complex components with exceptional accuracy, consistency, and efficiency while reducing dependence on manual operations. As industries continue to adopt digital manufacturing, artificial'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='artificial intelligence, and smart factory concepts, CNC machines will remain one of the most important technologies driving innovation and industrial development worldwide.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Machine Components: A CNC machine consists of several precision-engineered mechanical, electrical, and electronic components that work together to manufacture parts with high accuracy and'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='high accuracy and repeatability. The machine bed forms the foundation of the entire system and is generally made from high-grade cast iron or polymer concrete to provide rigidity and absorb'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='rigidity and absorb vibrations generated during machining. Mounted on the machine bed are the column, saddle, worktable, spindle head, guideways, and other structural elements. The spindle is one of'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='spindle is one of the most critical components because it rotates the cutting tool or workpiece at controlled speeds ranging from a few hundred to several thousand revolutions per minute depending on'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='minute depending on the application. Servo motors precisely drive each machine axis through ball screws, while linear guideways ensure smooth and accurate motion with minimal friction. Encoders'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='friction. Encoders continuously monitor axis positions and provide feedback to the CNC controller, allowing real-time error correction. The Automatic Tool Changer (ATC) stores multiple cutting tools'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='cutting tools and automatically exchanges them during machining, significantly reducing setup time and improving productivity. Coolant and lubrication systems control temperature, reduce friction,'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='reduce friction, extend tool life, and improve surface finish. Together, these components enable CNC machines to achieve micron-level accuracy, high repeatability, and reliable performance in'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='performance in industrial manufacturing.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC Programmer'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC Programmer is a manufacturing professional responsible for creating the instructions that control a CNC machine. These instructions, commonly written in the form of G-codes and M-codes, define'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and M-codes, define every aspect of the machining process, including tool paths, spindle speeds, feed rates, tool changes, coolant activation, and machining sequences. The programmer begins by'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='begins by studying the engineering drawing or 3D CAD model of the component, understanding dimensional tolerances, surface finish requirements, and material specifications. Using Computer-Aided'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Computer-Aided Manufacturing (CAM) software such as Mastercam, Siemens NX CAM, SolidCAM, Fusion 360, or Edgecam, the programmer generates the machining strategy and converts it into machine-readable'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='machine-readable code through a post-processor. The program is then verified using simulation software to detect collisions, over-travel, or programming errors before being transferred to the CNC'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='to the CNC machine.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC programmer must possess a strong understanding of machining processes, cutting tools, workholding methods, material properties, cutting parameters, and machine capabilities. They are'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='They are responsible for selecting appropriate cutting speeds, feed rates, depths of cut, and machining operations to maximize productivity while maintaining dimensional accuracy and tool life. In'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and tool life. In modern manufacturing, CNC programmers also optimize cycle times, reduce material waste, and improve production efficiency by implementing advanced machining strategies such as'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='strategies such as high-speed machining, adaptive toolpaths, and multi-axis programming. Their work directly influences product quality, manufacturing cost, and production throughput.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='CNC Operator'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='A CNC Operator is the person responsible for setting up, operating, and monitoring CNC machines during production. Unlike the programmer, who develops the machining program, the operator executes the'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='executes the program on the machine and ensures that production proceeds safely and efficiently. Before machining begins, the operator installs the required cutting tools, secures the workpiece using'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='the workpiece using appropriate fixtures or chucks, sets the work coordinate system, measures tool offsets, and loads the CNC program into the controller. Once the machine is ready, the operator'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='ready, the operator starts the machining cycle and continuously monitors the machine for abnormal sounds, excessive vibration, tool wear, coolant flow, or unexpected alarms.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='During production, the CNC operator periodically measures finished components using precision measuring instruments such as vernier calipers, micrometers, bore gauges, height gauges, and coordinate'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and coordinate measuring machines (CMMs) to verify that all dimensions remain within specified tolerances. If any deviation is observed, the operator may adjust tool offsets or replace worn cutting'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='worn cutting tools to maintain product quality. The operator is also responsible for maintaining cleanliness, performing routine machine maintenance, ensuring proper lubrication and coolant levels,'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and coolant levels, and following workplace safety procedures. A skilled CNC operator combines practical machining knowledge with attention to detail, enabling consistent production of high-quality'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='of high-quality components while minimizing downtime and material wastage.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Difference Between a CNC Programmer and a CNC Operator\nCNC Programmer\tCNC Operator\nCreates and edits CNC programs.\tRuns and monitors CNC machines.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Writes G-code and M-code manually or using CAM software.\tLoads and executes CNC programs.\nPlans machining strategies and tool paths.\tSets up tools, fixtures, and workpieces.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Selects cutting parameters and optimizes cycle time.\tMonitors machining operations and quality.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Requires strong programming and manufacturing knowledge.\tRequires practical machine operation and inspection skills.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Primarily works with CAD/CAM software and CNC controllers.\tPrimarily works on the shop floor with CNC machines.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='Focuses on process planning and optimization.\tFocuses on safe production and maintaining part quality.'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='In many small and medium-sized manufacturing companies, one experienced person may perform both programming and machine operation. In larger industries, however, CNC programmers and CNC operators'),
#  Document(metadata={'source': 'CNC.txt'}, page_content='and CNC operators usually have separate responsibilities to improve productivity and specialization.')]

# %%
# If finalDocuments is a list of Document objects:
texts = [doc.page_content for doc in finalDocuments]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
print(embeddings)
# Out:
# model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %%
# vector Store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db

# %%
query = input("Enter your question for CNC : ")
docs = db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# Enter your question for CNC : what is CNC Machine
# CNC machines are widely used in:
# A CNC (Computer Numerical Control) machine is an automated manufacturing machine that is controlled by a computer using pre-programmed instructions called G-code. It performs machining operations
# 1) What is a CNC Machine?
# Definition (Interview Answer)
# CNC technology an indispensable part of modern engineering and industrial production.

# %%
pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.12/dist-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.4)

# %%
pip install langchain_huggingface
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.23.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.4.9)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.10.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.5.0)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-1.2.2

# %%
pip install embeddings
# Out:
# Collecting embeddings
#   Downloading embeddings-0.0.8-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from embeddings) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from embeddings) (2.34.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from embeddings) (2.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->embeddings) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->embeddings) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests->embeddings) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests->embeddings) (2026.6.17)
# Downloading embeddings-0.0.8-py3-none-any.whl (12 kB)
# Installing collected packages: embeddings
# Successfully installed embeddings-0.0.8

# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.14.3-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)
# Downloading faiss_cpu-1.14.3-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 15.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.14.3
